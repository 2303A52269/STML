# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52269/STML/blob/main/STML_ASS(6).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 1

# %%
import pandas as pd
data=[[10,90,85,1,100,1],
      [5,60,70,0,80,0],
      [15,95,90,1,100,1],
      [2,30,50,0,40,0],
      [12,85,88,1,90,1],
      [8,75,65,0,70,0],
      [14,92,93,1,95,1],
      [3,50,55,0,60,0],
      [11,88,80,1,85,1],
      [6,65,60,0,75,0]]
df=pd.DataFrame(data,columns=['Study Hours per Week', 'Class Attendance (%)', 'Previous Exam Score (%)','Participation in Group Study', 'Submission of Assignments (%)', 'Pass/Fail'])
df
# Out:
#    Study Hours per Week  Class Attendance (%)  Previous Exam Score (%)  \
# 0                    10                    90                       85
# 1                     5                    60                       70
# 2                    15                    95                       90
# 3                     2                    30                       50
# 4                    12                    85                       88
# 5                     8                    75                       65
# 6                    14                    92                       93
# 7                     3                    50                       55
# 8                    11                    88                       80
# 9                     6                    65                       60
#
#    Participation in Group Study  Submission of Assignments (%)  Pass/Fail
# 0                             1                            100          1
# 1                             0                             80          0
# 2                             1                            100          1
# 3                             0                             40          0
# 4                             1                             90          1
# 5                             0                             70          0
# 6                             1                             95          1
# 7                             0                             60          0
# 8                             1                             85          1
# 9                             0                             75          0

# %%
df.to_csv('Student_data.csv', index=False)
df
# Out:
#    Study Hours per Week  Class Attendance (%)  Previous Exam Score (%)  \
# 0                    10                    90                       85
# 1                     5                    60                       70
# 2                    15                    95                       90
# 3                     2                    30                       50
# 4                    12                    85                       88
# 5                     8                    75                       65
# 6                    14                    92                       93
# 7                     3                    50                       55
# 8                    11                    88                       80
# 9                     6                    65                       60
#
#    Participation in Group Study  Submission of Assignments (%)  Pass/Fail
# 0                             1                            100          1
# 1                             0                             80          0
# 2                             1                            100          1
# 3                             0                             40          0
# 4                             1                             90          1
# 5                             0                             70          0
# 6                             1                             95          1
# 7                             0                             60          0
# 8                             1                             85          1
# 9                             0                             75          0

# %%
x=df.drop('Pass/Fail', axis=1)
y=df['Pass/Fail']

# %%
import numpy as np
list=[2.0,3.0,7.0,1.0,5.0]
weight=np.array(list)
weight
# Out:
# array([2., 3., 7., 1., 5.])

# %%
def update(p,e,i):
  for j in range(len(weight)):
    weight[j]=weight[j]+p*e*float(x.iloc[i:i+1,j:j+1],values)

# %%
print(x.iloc[0:1,1:2])
# Out:
#    Class Attendance (%)
# 0                    90

# %%
learning_rate=0.001
def error(yp,i):
  e=y[i]-yp
  if(e!=0):
    update(learning_rate,e,i)

# %%
yp=-1
import numpy as np
for k in range(6):
  for i in range(len(x)):
    z=np.dot(x[i:i+1],weight)
    if z>0:
      yp=1
    else:
        yp=0
        error(yp,i)
#print(yp)

# %%
print("Trained Weights:", weight)
#prediction Function
def perception_predict(x, weights):
  z=np.dot(x, weights)
  return 1 if z>=0 else 0

# Test the model
correct_predictions=0
for i in range(len(x)):
  prediction= perception_predict(x[i:i+1], weight)
  if prediction==y[i]:
    correct_predictions+=1

#Accuracy calculation
accuracy=correct_predictions/len(x)
print(f"Sccuracy: {accuracy*100:.2f}%")
# Out:
# Trained Weights: [2. 3. 7. 1. 5.]
# Sccuracy: 50.00%

# %% [markdown]
# Question 2

# %%
import pandas as pd
diabetes=pd.read_csv('/archive (7).zip')
diabetes.head()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# 0              No              Yes      Yes     Yes  Positive
# 1             Yes               No      Yes      No  Positive
# 2              No              Yes      Yes      No  Positive
# 3              No               No       No      No  Positive
# 4             Yes              Yes      Yes     Yes  Positive

# %%
target_var=diabetes['class']
target_var.head()
# Out:
# 0    Positive
# 1    Positive
# 2    Positive
# 3    Positive
# 4    Positive
# Name: class, dtype: object

# %%
one_values=["Male", "yes"]
zero_values=["Female", "No"]

for column in diabetes.columns:
  diabetes[column]=diabetes[column].replace(to_replace=one_values, value=1)
  diabetes[column]=diabetes[column].replace(to_replace=zero_values, value=0)
diabetes
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40       1        0        Yes                  0      Yes          0
# 1     58       1        0          0                  0      Yes          0
# 2     41       1      Yes          0                  0      Yes        Yes
# 3     45       1        0          0                Yes      Yes        Yes
# 4     60       1      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39       0      Yes        Yes                Yes        0        Yes
# 516   48       0      Yes        Yes                Yes      Yes        Yes
# 517   58       0      Yes        Yes                Yes      Yes        Yes
# 518   32       0        0          0                  0      Yes          0
# 519   42       1        0          0                  0        0          0
#
#     Genital thrush visual blurring Itching Irritability delayed healing  \
# 0                0               0     Yes            0             Yes
# 1                0             Yes       0            0               0
# 2                0               0     Yes            0             Yes
# 3              Yes               0     Yes            0             Yes
# 4                0             Yes     Yes          Yes             Yes
# ..             ...             ...     ...          ...             ...
# 515              0               0     Yes            0             Yes
# 516              0               0     Yes          Yes             Yes
# 517              0             Yes       0            0               0
# 518              0             Yes     Yes            0             Yes
# 519              0               0       0            0               0
#
#     partial paresis muscle stiffness Alopecia Obesity     class
# 0                 0              Yes      Yes     Yes  Positive
# 1               Yes                0      Yes       0  Positive
# 2                 0              Yes      Yes       0  Positive
# 3                 0                0        0       0  Positive
# 4               Yes              Yes      Yes     Yes  Positive
# ..              ...              ...      ...     ...       ...
# 515             Yes                0        0       0  Positive
# 516             Yes                0        0       0  Positive
# 517             Yes              Yes        0     Yes  Positive
# 518               0                0      Yes       0  Negative
# 519               0                0        0       0  Negative
#
# [520 rows x 17 columns]

# %%
one_values=["Positive"]
zero_values=["negative"]
target_var=target_var.replace(to_replace=one_values, value=1)
target_var=target_var.replace(to_replace=zero_values, value=0)
target_var.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: class, dtype: object

# %%
import numpy as np
list1=[0.21,0.60,0.78,0.22,0.62,
       0.53,0.39,0.36,0.04,0.87,
       0.89,0.13,0.79,0.13,0.50,
       0.80]
weights=np.array(list1)
weights
# Out:
# array([0.21, 0.6 , 0.78, 0.22, 0.62, 0.53, 0.39, 0.36, 0.04, 0.87, 0.89,
#        0.13, 0.79, 0.13, 0.5 , 0.8 ])

# %%
diabetes.iloc[0:1].values
# Out:
# array([[40, 1, 0, 'Yes', 0, 'Yes', 0, 0, 0, 'Yes', 0, 'Yes', 0, 'Yes',
#         'Yes', 'Yes', 'Positive']], dtype=object)

# %%
import numpy as np

def update(p,e,i):
  for j in range(len(weights)):
    weights[j]=weights[j]+p*e*float(diabetes.iloc[i:i+1,j:j+1].values)

cp=0
learning_rate=0.001
def error(yp,i):
  e=target_var[i]-yp
  if(e!=0):
    update(learning_rate,e,i)
  return cp

list1=[0.21,0.60,0.78,0.22,0.62,
       0.53,0.39,0.036,0.04,0.87,
       0.89,0.13,0.79,0.50,
       0.80,0.1, 0.5]

weights=np.array(list1)

def perception_predict(x,weights):
  x = np.array(x).flatten()
  return 1 if z>=0 else 0

# Test the model
correct_predictions=0
for i in range(len(diabetes)):
  prediction=perception_predict(diabetes.iloc[i:i+1].values, weights)
  if prediction==target_var[i]:
    correct_predictions+=1

#accuracy Calculation
accuracy=correct_predictions/len(diabetes)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 61.54%
